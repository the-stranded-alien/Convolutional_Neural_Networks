# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.layers import *
from keras.models import Sequential
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. Loading Data

# %% [markdown]
# #### 1.1 Defining Required Dataset Paths

# %%
BASE_FOLDER_PATH = "Dataset/AnimalDataset/"
DATA_PATH = BASE_FOLDER_PATH + "All_Images/"
TRAIN_PATH = BASE_FOLDER_PATH + "Train_Images/"
VALID_PATH = BASE_FOLDER_PATH + "Validation_Images/"

# %% [markdown]
# #### 1.2 Checking The Total Number Of Images In Dataset Of Each Class

# %%
folders = os.listdir(DATA_PATH)
for f in folders:
    path = DATA_PATH + f
    print(str(len(os.listdir(path))) + " Images For " + str(f).upper() + " Class")
# Out:
# 202 Images For CATS Class
# 202 Images For DOGS Class
# 202 Images For HORSES Class
# 202 Images For HUMANS Class

# %% [markdown]
#  - **We Need To Split Our Data Into Separate Folders For Training And Validation So That We Can Make Training And Validation Generators Later**

# %% [markdown]
# #### 1.3 Creating Training and Validation Images Directory If Not Available

# %%
if not os.path.isdir(TRAIN_PATH):
    os.mkdir(TRAIN_PATH)
    
if not os.path.isdir(VALID_PATH):
    os.mkdir(VALID_PATH)

# %% [markdown]
# #### 1.4 Creating Subfolders For Each Class In Both Training and Validation Images Directory

# %%
classes = ["dogs", "cats", "horses", "humans"]

for each_class in classes:
    sub_path_train = os.path.join(TRAIN_PATH, each_class)
    sub_path_valid = os.path.join(VALID_PATH, each_class)
    
    if not os.path.isdir(sub_path_train):
        os.mkdir(sub_path_train)
        
    if not os.path.isdir(sub_path_valid):
        os.mkdir(sub_path_valid)

# %% [markdown]
# #### 1.5 Splitting The Data And Copying It To The Created Directories

# %%
SPLIT = 0.9

for classSubFolder in os.listdir(DATA_PATH):
    
    # Iterating Over Each Class Folder     
    cur_class_path = DATA_PATH + classSubFolder
    images_cur_class = os.listdir(cur_class_path)
    
    # Splitting The Data Into Train And Validation Images For Current Class
    split_size = int(SPLIT*len(images_cur_class))
    train_images = images_cur_class[:split_size]
    valid_images = images_cur_class[split_size:]
    print("\n# Training Images For " + str(classSubFolder).upper() + " : " + str(len(train_images)))
    print("Validation Images For " + str(classSubFolder).upper() + " : " + str(len(valid_images)))
    
    # Copying Training Images
    for image_path in train_images:
        src_path = os.path.join(cur_class_path, image_path)
        dest_path = os.path.join(TRAIN_PATH + classSubFolder, image_path)
        shutil.copy(src_path, dest_path)
        
    # Copying Validation Images    
    for image_path in valid_images:
        src_path = os.path.join(cur_class_path, image_path)
        dest_path = os.path.join(VALID_PATH + classSubFolder, image_path)
        shutil.copy(src_path, dest_path)
# Out:
# # Training Images For CATS : 181
# Validation Images For CATS : 21
#
# # Training Images For DOGS : 181
# Validation Images For DOGS : 21
#
# # Training Images For HORSES : 181
# Validation Images For HORSES : 21
#
# # Training Images For HUMANS : 181
# Validation Images For HUMANS : 21

# %% [markdown]
# ## 2. Creating Training And Validation Generators
#
#  - A Image Data Generator First Goes To The Base Directory Specified
#  - Then It Reads Images According To The Subfolders Name As Classes.
#  - Then It Convert Images Into Arrays And Apply Required Operations.
#  - It Also Converts The Class Labels Into One Hot Vectors.
#  - Thus This Can Be Used To Easily Feed The Data To Any Model.
#  - This Helps To Load Large Datasets In Form Of Small Batches.
#  - These Batches Can Be Feed One By One To The Model

# %% [markdown]
# #### 2.1 Training Generator

# %%
train_gen = ImageDataGenerator(rescale=1.0/255.0)
train_generator = train_gen.flow_from_directory(
    TRAIN_PATH,
    target_size = (150,150),
    batch_size = 32,
    class_mode = 'categorical'
)
# Out:
# Found 724 images belonging to 4 classes.

# %% [markdown]
# #### 2.2 Validation Generator

# %%
val_gen = ImageDataGenerator(rescale=1.0/255.0)
validation_generator = val_gen.flow_from_directory(
    VALID_PATH,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical'
)
# Out:
# Found 84 images belonging to 4 classes.

# %% [markdown]
# ## 3. Visualising The Data

# %% [markdown]
# #### 3.1 Visualising The Training Images

# %%
for x, y in train_generator:
    print("\nShape Of X_Train (For 1 Batch) : ", x.shape)
    print("\nShape Of Y_Train (For 1 Batch) : ", y.shape)
    plt.figure(figsize=(16,8))
    for i in range(1, len(x)+1):
        plt.subplot(4,8,i)
        plt.imshow(x[i-1])
        plt.axis("off")
    plt.tight_layout()
    print("\nOne Batch Of Training Images")
    plt.show()
    break
# Out:
# Shape Of X_Train (For 1 Batch) :  (32, 150, 150, 3)
#
# Shape Of Y_Train (For 1 Batch) :  (32, 4)
#
# One Batch Of Training Images

# %% [markdown]
# #### 3.1 Visualising The Validation Images

# %%
for x, y in validation_generator:
    print("\nShape Of X_Validation (For 1 Batch) : ", x.shape)
    print("\nShape Of Y_Validation (For 1 Batch) : ", y.shape)
    plt.figure(figsize=(16,4))
    for i in range(1, len(x)+1):
        plt.subplot(2,8,i)
        plt.imshow(x[i-1])
        plt.axis("off")
    plt.tight_layout()
    print("\nOne Batch Of Validation Images")
    plt.show()
    break
# Mini Batch of 32 images
# Out:
# Shape Of X_Validation (For 1 Batch) :  (16, 150, 150, 3)
#
# Shape Of Y_Validation (For 1 Batch) :  (16, 4)
#
# One Batch Of Validation Images

# %% [markdown]
# ## 4. Defining The CNN Model

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)))
model.add(MaxPool2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D((2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPool2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D((2,2)))
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 34, 34, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 15, 64)        73792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 16)          9232
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                25664
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 202,196
# Trainable params: 202,196
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Compiling The Model

# %%
adam = optimizers.adam(lr=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# ## 6. Training The Model
#
# - Training The Model Using Train And Validation Generator.
# - **model.fit( )** -> Useful When Dataset Is Small And It Can Fit Inside The Memory.
# - **model.fit_generator( )** -> Useful When The Dataset Is Large And Can't Fit Inside The Memory.

# %%
print("The Labels We Got : ", set(train_generator.labels))
# Out:
# The Labels We Got :  {0, 1, 2, 3}

# %%
history = model.fit_generator(
    train_generator,
    epochs = 60,
    steps_per_epoch = 7, # Batchs Per Epoch
    validation_data=validation_generator,
    validation_steps = 4  
)
# Out:
# Epoch 1/60
# 7/7 [==============================] - 5s 670ms/step - loss: 1.3839 - accuracy: 0.2689 - val_loss: 1.3939 - val_accuracy: 0.2500
# Epoch 2/60
# 7/7 [==============================] - 4s 615ms/step - loss: 1.3689 - accuracy: 0.3527 - val_loss: 1.3668 - val_accuracy: 0.3654
# Epoch 3/60
# 7/7 [==============================] - 4s 610ms/step - loss: 1.3800 - accuracy: 0.3304 - val_loss: 1.3518 - val_accuracy: 0.3846
# Epoch 4/60
# 7/7 [==============================] - 4s 635ms/step - loss: 1.3740 - accuracy: 0.2925 - val_loss: 1.3633 - val_accuracy: 0.3750
# Epoch 5/60
# 7/7 [==============================] - 5s 686ms/step - loss: 1.3559 - accuracy: 0.4152 - val_loss: 1.3495 - val_accuracy: 0.3269
# Epoch 6/60
# 7/7 [==============================] - 5s 666ms/step - loss: 1.3423 - accuracy: 0.4286 - val_loss: 1.3382 - val_accuracy: 0.3846
# Epoch 7/60
# 7/7 [==============================] - 5s 662ms/step - loss: 1.3478 - accuracy: 0.3585 - val_loss: 1.3127 - val_accuracy: 0.3750
# Epoch 8/60
# 7/7 [==============================] - 5s 689ms/step - loss: 1.3318 - accuracy: 0.3214 - val_loss: 1.3392 - val_accuracy: 0.3269
# Epoch 9/60
# 7/7 [==============================] - 5s 662ms/step - loss: 1.3156 - accuracy: 0.4062 - val_loss: 1.2890 - val_accuracy: 0.4231
# Epoch 10/60
# 7/7 [==============================] - 5s 692ms/step - loss: 1.2789 - accuracy: 0.4330 - val_loss: 1.2656 - val_accuracy: 0.3594
# Epoch 11/60
# 7/7 [==============================] - 5s 678ms/step - loss: 1.2681 - accuracy: 0.4732 - val_loss: 1.1712 - val_accuracy: 0.5385
# Epoch 12/60
# 7/7 [==============================] - 5s 669ms/step - loss: 1.2215 - accuracy: 0.4955 - val_loss: 1.0268 - val_accuracy: 0.3654
# Epoch 13/60
# 7/7 [==============================] - 5s 677ms/step - loss: 1.2161 - accuracy: 0.3929 - val_loss: 1.1896 - val_accuracy: 0.4062
# Epoch 14/60
# 7/7 [==============================] - 4s 637ms/step - loss: 1.1653 - accuracy: 0.4650 - val_loss: 1.2150 - val_accuracy: 0.4615
# Epoch 15/60
# 7/7 [==============================] - 5s 673ms/step - loss: 1.1601 - accuracy: 0.4732 - val_loss: 1.1614 - val_accuracy: 0.5192
# Epoch 16/60
# 7/7 [==============================] - 5s 682ms/step - loss: 1.0883 - accuracy: 0.4955 - val_loss: 1.2113 - val_accuracy: 0.4688
# Epoch 17/60
# 7/7 [==============================] - 5s 662ms/step - loss: 1.1418 - accuracy: 0.4811 - val_loss: 1.1658 - val_accuracy: 0.4423
# Epoch 18/60
# 7/7 [==============================] - 5s 686ms/step - loss: 1.0928 - accuracy: 0.5089 - val_loss: 0.7755 - val_accuracy: 0.5192
# Epoch 19/60
# 7/7 [==============================] - 5s 681ms/step - loss: 1.0797 - accuracy: 0.5134 - val_loss: 1.2666 - val_accuracy: 0.4375
# Epoch 20/60
# 7/7 [==============================] - 5s 701ms/step - loss: 1.0511 - accuracy: 0.5446 - val_loss: 1.0209 - val_accuracy: 0.5769
# Epoch 21/60
# 7/7 [==============================] - 5s 679ms/step - loss: 1.0361 - accuracy: 0.5714 - val_loss: 1.2985 - val_accuracy: 0.4038
# Epoch 22/60
# 7/7 [==============================] - 5s 693ms/step - loss: 1.0059 - accuracy: 0.5670 - val_loss: 1.2356 - val_accuracy: 0.4531
# Epoch 23/60
# 7/7 [==============================] - 5s 660ms/step - loss: 0.9454 - accuracy: 0.5708 - val_loss: 0.9291 - val_accuracy: 0.5769
# Epoch 24/60
# 7/7 [==============================] - 5s 660ms/step - loss: 0.9444 - accuracy: 0.5802 - val_loss: 0.9601 - val_accuracy: 0.4808
# Epoch 25/60
# 7/7 [==============================] - 5s 691ms/step - loss: 1.0202 - accuracy: 0.5312 - val_loss: 1.0948 - val_accuracy: 0.5781
# Epoch 26/60
# 7/7 [==============================] - 5s 684ms/step - loss: 0.9366 - accuracy: 0.5848 - val_loss: 1.0578 - val_accuracy: 0.4615
# Epoch 27/60
# 7/7 [==============================] - 5s 687ms/step - loss: 0.8916 - accuracy: 0.6205 - val_loss: 1.3438 - val_accuracy: 0.4808
# Epoch 28/60
# 7/7 [==============================] - 5s 689ms/step - loss: 0.9628 - accuracy: 0.5848 - val_loss: 0.6572 - val_accuracy: 0.5000
# Epoch 29/60
# 7/7 [==============================] - 5s 670ms/step - loss: 0.9100 - accuracy: 0.6071 - val_loss: 1.2678 - val_accuracy: 0.5577
# Epoch 30/60
# 7/7 [==============================] - 5s 653ms/step - loss: 0.9276 - accuracy: 0.6085 - val_loss: 0.9798 - val_accuracy: 0.5577
# Epoch 31/60
# 7/7 [==============================] - 5s 654ms/step - loss: 0.9121 - accuracy: 0.6085 - val_loss: 1.1065 - val_accuracy: 0.5000
# Epoch 32/60
# 7/7 [==============================] - 5s 677ms/step - loss: 0.8268 - accuracy: 0.6920 - val_loss: 1.0705 - val_accuracy: 0.5385
# Epoch 33/60
# 7/7 [==============================] - 5s 687ms/step - loss: 0.9292 - accuracy: 0.5938 - val_loss: 1.3880 - val_accuracy: 0.5577
# Epoch 34/60
# 7/7 [==============================] - 5s 687ms/step - loss: 0.9145 - accuracy: 0.6071 - val_loss: 1.0137 - val_accuracy: 0.5625
# Epoch 35/60
# 7/7 [==============================] - 5s 645ms/step - loss: 0.8717 - accuracy: 0.6038 - val_loss: 1.1501 - val_accuracy: 0.5000
# Epoch 36/60
# 7/7 [==============================] - 5s 673ms/step - loss: 0.8201 - accuracy: 0.6429 - val_loss: 1.1049 - val_accuracy: 0.5385
# Epoch 37/60
# 7/7 [==============================] - 5s 698ms/step - loss: 0.8827 - accuracy: 0.6295 - val_loss: 0.9746 - val_accuracy: 0.5469
# Epoch 38/60
# 7/7 [==============================] - 5s 696ms/step - loss: 0.8080 - accuracy: 0.6652 - val_loss: 1.0439 - val_accuracy: 0.5385
# Epoch 39/60
# 7/7 [==============================] - 5s 668ms/step - loss: 0.7719 - accuracy: 0.6473 - val_loss: 1.3161 - val_accuracy: 0.5769
# Epoch 40/60
# 7/7 [==============================] - 5s 670ms/step - loss: 0.9235 - accuracy: 0.6132 - val_loss: 0.9387 - val_accuracy: 0.4844
# Epoch 41/60
# 7/7 [==============================] - 5s 655ms/step - loss: 0.7711 - accuracy: 0.6604 - val_loss: 0.9993 - val_accuracy: 0.4808
# Epoch 42/60
# 7/7 [==============================] - 5s 680ms/step - loss: 0.8223 - accuracy: 0.6652 - val_loss: 1.4617 - val_accuracy: 0.5192
# Epoch 43/60
# 7/7 [==============================] - 5s 699ms/step - loss: 0.8210 - accuracy: 0.6651 - val_loss: 0.6982 - val_accuracy: 0.5938
# Epoch 44/60
# 7/7 [==============================] - 5s 709ms/step - loss: 0.7613 - accuracy: 0.6875 - val_loss: 1.1842 - val_accuracy: 0.5000
# Epoch 45/60
# 7/7 [==============================] - 5s 730ms/step - loss: 0.7743 - accuracy: 0.6562 - val_loss: 0.7975 - val_accuracy: 0.5962
# Epoch 46/60
# 7/7 [==============================] - 5s 717ms/step - loss: 0.8401 - accuracy: 0.6384 - val_loss: 1.0798 - val_accuracy: 0.5156
# Epoch 47/60
# 7/7 [==============================] - 5s 662ms/step - loss: 0.8386 - accuracy: 0.6415 - val_loss: 0.9973 - val_accuracy: 0.6346
# Epoch 48/60
# 7/7 [==============================] - 5s 679ms/step - loss: 0.7009 - accuracy: 0.7455 - val_loss: 1.1775 - val_accuracy: 0.5000
# Epoch 49/60
# 7/7 [==============================] - 5s 678ms/step - loss: 0.7630 - accuracy: 0.6696 - val_loss: 0.9788 - val_accuracy: 0.5469
# Epoch 50/60
# 7/7 [==============================] - 5s 695ms/step - loss: 0.7319 - accuracy: 0.6830 - val_loss: 1.1158 - val_accuracy: 0.4808
# Epoch 51/60
# 7/7 [==============================] - 5s 678ms/step - loss: 0.8557 - accuracy: 0.6652 - val_loss: 1.0279 - val_accuracy: 0.6346
# Epoch 52/60
# 7/7 [==============================] - 5s 649ms/step - loss: 0.7049 - accuracy: 0.7217 - val_loss: 1.0403 - val_accuracy: 0.5469
# Epoch 53/60
# 7/7 [==============================] - 5s 695ms/step - loss: 0.7250 - accuracy: 0.7098 - val_loss: 0.9932 - val_accuracy: 0.5769
# Epoch 54/60
# 7/7 [==============================] - 5s 677ms/step - loss: 0.8185 - accuracy: 0.6696 - val_loss: 0.3561 - val_accuracy: 0.5192
# Epoch 55/60
# 7/7 [==============================] - 5s 651ms/step - loss: 0.7163 - accuracy: 0.7170 - val_loss: 1.1370 - val_accuracy: 0.5312
# Epoch 56/60
# 7/7 [==============================] - 5s 696ms/step - loss: 0.6951 - accuracy: 0.7009 - val_loss: 0.7976 - val_accuracy: 0.6154
# Epoch 57/60
# 7/7 [==============================] - 5s 681ms/step - loss: 0.6626 - accuracy: 0.7500 - val_loss: 0.8691 - val_accuracy: 0.5385
# Epoch 58/60
# 7/7 [==============================] - 5s 652ms/step - loss: 0.7920 - accuracy: 0.6651 - val_loss: 1.0924 - val_accuracy: 0.5938
# Epoch 59/60
# 7/7 [==============================] - 5s 682ms/step - loss: 0.6463 - accuracy: 0.7321 - val_loss: 0.9538 - val_accuracy: 0.4808
# Epoch 60/60
# 7/7 [==============================] - 5s 689ms/step - loss: 0.7331 - accuracy: 0.6786 - val_loss: 0.9700 - val_accuracy: 0.5769

# %% [markdown]
# ## 7. Visualising The Results

# %% [markdown]
# #### 7.1 Training And Validation Accuracy

# %%
train_acc = history.history["accuracy"]
valid_acc = history.history["val_accuracy"]

plt.style.use("seaborn")
plt.plot(train_acc, label="Training Accuracy")
plt.plot(valid_acc, label="Validation Accuracy")
plt.title("Training And Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# #### 7.2 Training And Validation Loss

# %%
train_loss = history.history["loss"]
valid_loss = history.history["val_loss"]

plt.style.use("seaborn")
plt.plot(train_loss, label="Training Loss")
plt.plot(valid_loss, label="Validation Loss")
plt.title("Training And Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 8. Results

# %% [markdown]
# #### 8.1 Training Accuracy

# %%
train_loss, train_accuracy = model.evaluate_generator(train_generator)
print("\nTraining Accuracy : ", 100 * round(train_accuracy, 4), "%")
# Out:
# Training Accuracy :  69.89 %

# %% [markdown]
# #### 8.2 Validation Accuracy

# %%
valid_loss, valid_accuracy = model.evaluate_generator(validation_generator)
print("\nValidation Accuracy : ", 100 * round(valid_accuracy, 4), "%")
# Out:
# Validation Accuracy :  54.76 %

# %% [markdown]
# # Data Augmentation In Image Pipelines
#
#  - **We Can See That The Model Is Overfitting And Their Is A Lot Of Inconsistency In Training And Validation Accuracies And Losses.**
#
#  - **This Is Due To The Small Quantity Of Dataset.**
#
#  - **So, We Will Use The Regularization Technique Known As Data Augmentation.**
#
#  - **This Will Help Us Create Different Images With Different Operations Applied To Them.**
#
#  - **This Should Help To Reduce Overfitting By Making The Model More Robust.**

# %% [markdown]
# ## 9. Creating Training And Validation Generators With Data Augmentation

# %% [markdown]
# #### 9.1 Training Image Generator

# %%
train_image_gen = ImageDataGenerator(
    rescale = 1/255.0,
    rotation_range = 40,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    shear_range = 0.2,
    zoom_range = 0.3,
    horizontal_flip = True
)

train_generator_aug = train_image_gen.flow_from_directory(
    TRAIN_PATH,
    target_size = (150,150),
    batch_size = 32,
    class_mode = 'categorical'
)
# Out:
# Found 724 images belonging to 4 classes.

# %% [markdown]
# #### 9.2 Validation Image Generator
#
#  - No Augmentation Is Done On Validation Data

# %%
val_image_gen = ImageDataGenerator(rescale=1.0/255.0)
validation_generator_aug = val_image_gen.flow_from_directory(
    VALID_PATH,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical'
)
# Out:
# Found 84 images belonging to 4 classes.

# %% [markdown]
# ## 10. Visualising The Augmented Data
#
#  - Only Training Data Is Augmented, So, We Will Visualise That Only.

# %%
for x, y in train_generator_aug:
    print("\nShape Of X_Train (For 1 Batch) : ", x.shape)
    print("\nShape Of Y_Train (For 1 Batch) : ", y.shape)
    plt.figure(figsize=(16,8))
    for i in range(1, len(x)+1):
        plt.subplot(4,8,i)
        plt.imshow(x[i-1])
        plt.axis("off")
    plt.tight_layout()
    print("\nOne Batch Of Augmented Training Images")
    plt.show()
    break
# Out:
# Shape Of X_Train (For 1 Batch) :  (32, 150, 150, 3)
#
# Shape Of Y_Train (For 1 Batch) :  (32, 4)
#
# One Batch Of Augmented Training Images

# %% [markdown]
# ## 11. Defining New CNN Model For Augmented Data

# %%
model_aug = Sequential()
model_aug.add(Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)))
model_aug.add(MaxPool2D((2,2)))
model_aug.add(Conv2D(64, (3,3), activation='relu'))
model_aug.add(MaxPool2D((2,2)))
model_aug.add(Conv2D(128, (3,3), activation='relu'))
model_aug.add(Dropout(0.25))
model_aug.add(MaxPool2D((2,2)))
model_aug.add(Conv2D(64, (3,3), activation='relu'))
model_aug.add(MaxPool2D((2,2)))
model_aug.add(Conv2D(16, (3,3), activation='relu'))
model_aug.add(Flatten())
model_aug.add(Dense(64, activation='relu'))
model_aug.add(Dense(4, activation='softmax'))
model_aug.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 34, 34, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 15, 64)        73792
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 16)          9232
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                25664
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 202,196
# Trainable params: 202,196
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 12. Compiling And Training The New CNN Model

# %%
adam = optimizers.adam(lr=1e-4)
model_aug.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

history = model_aug.fit_generator(
    train_generator_aug,
    epochs = 60,
    steps_per_epoch = 7,
    validation_data=validation_generator_aug,
    validation_steps = 4  
)
# Out:
# Epoch 1/60
# 7/7 [==============================] - 5s 765ms/step - loss: 1.3949 - accuracy: 0.2500 - val_loss: 1.3809 - val_accuracy: 0.2500
# Epoch 2/60
# 7/7 [==============================] - 5s 693ms/step - loss: 1.3901 - accuracy: 0.2500 - val_loss: 1.3798 - val_accuracy: 0.2692
# Epoch 3/60
# 7/7 [==============================] - 5s 721ms/step - loss: 1.3922 - accuracy: 0.2054 - val_loss: 1.3631 - val_accuracy: 0.2692
# Epoch 4/60
# 7/7 [==============================] - 5s 759ms/step - loss: 1.3832 - accuracy: 0.2768 - val_loss: 1.3940 - val_accuracy: 0.2656
# Epoch 5/60
# 7/7 [==============================] - 5s 770ms/step - loss: 1.3839 - accuracy: 0.2768 - val_loss: 1.3899 - val_accuracy: 0.3269
# Epoch 6/60
# 7/7 [==============================] - 5s 754ms/step - loss: 1.3849 - accuracy: 0.2406 - val_loss: 1.3975 - val_accuracy: 0.2692
# Epoch 7/60
# 7/7 [==============================] - 5s 726ms/step - loss: 1.3860 - accuracy: 0.2500 - val_loss: 1.3816 - val_accuracy: 0.2969
# Epoch 8/60
# 7/7 [==============================] - 5s 731ms/step - loss: 1.3835 - accuracy: 0.3170 - val_loss: 1.3774 - val_accuracy: 0.4038
# Epoch 9/60
# 7/7 [==============================] - 5s 686ms/step - loss: 1.3806 - accuracy: 0.2925 - val_loss: 1.3567 - val_accuracy: 0.4038
# Epoch 10/60
# 7/7 [==============================] - 5s 713ms/step - loss: 1.3808 - accuracy: 0.3170 - val_loss: 1.3748 - val_accuracy: 0.3281
# Epoch 11/60
# 7/7 [==============================] - 5s 727ms/step - loss: 1.3771 - accuracy: 0.3036 - val_loss: 1.3707 - val_accuracy: 0.2692
# Epoch 12/60
# 7/7 [==============================] - 5s 709ms/step - loss: 1.3757 - accuracy: 0.2545 - val_loss: 1.3611 - val_accuracy: 0.2115
# Epoch 13/60
# 7/7 [==============================] - 5s 679ms/step - loss: 1.3661 - accuracy: 0.3302 - val_loss: 1.3757 - val_accuracy: 0.4062
# Epoch 14/60
# 7/7 [==============================] - 5s 686ms/step - loss: 1.3541 - accuracy: 0.3679 - val_loss: 1.3900 - val_accuracy: 0.2500
# Epoch 15/60
# 7/7 [==============================] - 5s 719ms/step - loss: 1.3649 - accuracy: 0.3214 - val_loss: 1.3266 - val_accuracy: 0.3846
# Epoch 16/60
# 7/7 [==============================] - 5s 732ms/step - loss: 1.3468 - accuracy: 0.4286 - val_loss: 1.3184 - val_accuracy: 0.3594
# Epoch 17/60
# 7/7 [==============================] - 5s 736ms/step - loss: 1.3222 - accuracy: 0.4018 - val_loss: 1.3063 - val_accuracy: 0.3077
# Epoch 18/60
# 7/7 [==============================] - 5s 720ms/step - loss: 1.3147 - accuracy: 0.3839 - val_loss: 1.2894 - val_accuracy: 0.3269
# Epoch 19/60
# 7/7 [==============================] - 5s 734ms/step - loss: 1.2815 - accuracy: 0.4018 - val_loss: 1.3140 - val_accuracy: 0.4062
# Epoch 20/60
# 7/7 [==============================] - 5s 674ms/step - loss: 1.2831 - accuracy: 0.4528 - val_loss: 1.5032 - val_accuracy: 0.4038
# Epoch 21/60
# 7/7 [==============================] - 5s 686ms/step - loss: 1.2336 - accuracy: 0.4340 - val_loss: 1.3647 - val_accuracy: 0.3654
# Epoch 22/60
# 7/7 [==============================] - 5s 725ms/step - loss: 1.3076 - accuracy: 0.3304 - val_loss: 1.4068 - val_accuracy: 0.4688
# Epoch 23/60
# 7/7 [==============================] - 5s 708ms/step - loss: 1.2955 - accuracy: 0.3839 - val_loss: 1.2837 - val_accuracy: 0.3269
# Epoch 24/60
# 7/7 [==============================] - 5s 720ms/step - loss: 1.2796 - accuracy: 0.3750 - val_loss: 0.9778 - val_accuracy: 0.3654
# Epoch 25/60
# 7/7 [==============================] - 5s 700ms/step - loss: 1.2065 - accuracy: 0.4811 - val_loss: 1.1680 - val_accuracy: 0.5312
# Epoch 26/60
# 7/7 [==============================] - 5s 717ms/step - loss: 1.2833 - accuracy: 0.4464 - val_loss: 1.0049 - val_accuracy: 0.4423
# Epoch 27/60
# 7/7 [==============================] - 5s 713ms/step - loss: 1.2370 - accuracy: 0.3839 - val_loss: 0.9624 - val_accuracy: 0.4423
# Epoch 28/60
# 7/7 [==============================] - 5s 697ms/step - loss: 1.2671 - accuracy: 0.4292 - val_loss: 1.4132 - val_accuracy: 0.4844
# Epoch 29/60
# 7/7 [==============================] - 5s 732ms/step - loss: 1.2277 - accuracy: 0.4375 - val_loss: 1.6047 - val_accuracy: 0.4038
# Epoch 30/60
# 7/7 [==============================] - 5s 737ms/step - loss: 1.2716 - accuracy: 0.3929 - val_loss: 0.8597 - val_accuracy: 0.5192
# Epoch 31/60
# 7/7 [==============================] - 5s 702ms/step - loss: 1.1820 - accuracy: 0.4575 - val_loss: 1.1592 - val_accuracy: 0.3906
# Epoch 32/60
# 7/7 [==============================] - 5s 733ms/step - loss: 1.1986 - accuracy: 0.4464 - val_loss: 1.2672 - val_accuracy: 0.4231
# Epoch 33/60
# 7/7 [==============================] - 5s 703ms/step - loss: 1.2629 - accuracy: 0.4330 - val_loss: 1.2403 - val_accuracy: 0.5000
# Epoch 34/60
# 7/7 [==============================] - 5s 699ms/step - loss: 1.2104 - accuracy: 0.4245 - val_loss: 1.2484 - val_accuracy: 0.5625
# Epoch 35/60
# 7/7 [==============================] - 5s 729ms/step - loss: 1.1932 - accuracy: 0.4464 - val_loss: 1.2082 - val_accuracy: 0.4615
# Epoch 36/60
# 7/7 [==============================] - 5s 697ms/step - loss: 1.1776 - accuracy: 0.5223 - val_loss: 1.3794 - val_accuracy: 0.5192
# Epoch 37/60
# 7/7 [==============================] - 5s 731ms/step - loss: 1.1549 - accuracy: 0.4911 - val_loss: 1.5671 - val_accuracy: 0.2969
# Epoch 38/60
# 7/7 [==============================] - 5s 701ms/step - loss: 1.2340 - accuracy: 0.4340 - val_loss: 1.0074 - val_accuracy: 0.5192
# Epoch 39/60
# 7/7 [==============================] - 5s 714ms/step - loss: 1.2721 - accuracy: 0.4152 - val_loss: 1.2625 - val_accuracy: 0.3462
# Epoch 40/60
# 7/7 [==============================] - 5s 733ms/step - loss: 1.1789 - accuracy: 0.4420 - val_loss: 1.2408 - val_accuracy: 0.5000
# Epoch 41/60
# 7/7 [==============================] - 5s 690ms/step - loss: 1.1965 - accuracy: 0.5142 - val_loss: 1.1008 - val_accuracy: 0.5385
# Epoch 42/60
# 7/7 [==============================] - 5s 734ms/step - loss: 1.1620 - accuracy: 0.4777 - val_loss: 1.1432 - val_accuracy: 0.5192
# Epoch 43/60
# 7/7 [==============================] - 5s 745ms/step - loss: 1.1309 - accuracy: 0.5714 - val_loss: 1.3231 - val_accuracy: 0.5156
# Epoch 44/60
# 7/7 [==============================] - 5s 725ms/step - loss: 1.2065 - accuracy: 0.5000 - val_loss: 1.3130 - val_accuracy: 0.4423
# Epoch 45/60
# 7/7 [==============================] - 5s 717ms/step - loss: 1.2138 - accuracy: 0.4241 - val_loss: 0.8479 - val_accuracy: 0.5192
# Epoch 46/60
# 7/7 [==============================] - 5s 677ms/step - loss: 1.1050 - accuracy: 0.4764 - val_loss: 1.1529 - val_accuracy: 0.5938
# Epoch 47/60
# 7/7 [==============================] - 5s 727ms/step - loss: 1.1701 - accuracy: 0.4732 - val_loss: 1.0138 - val_accuracy: 0.5385
# Epoch 48/60
# 7/7 [==============================] - 5s 688ms/step - loss: 1.1239 - accuracy: 0.5047 - val_loss: 0.8547 - val_accuracy: 0.5000
# Epoch 49/60
# 7/7 [==============================] - 5s 720ms/step - loss: 1.1511 - accuracy: 0.4643 - val_loss: 1.3642 - val_accuracy: 0.5625
# Epoch 50/60
# 7/7 [==============================] - 5s 682ms/step - loss: 1.1680 - accuracy: 0.4292 - val_loss: 1.0984 - val_accuracy: 0.5192
# Epoch 51/60
# 7/7 [==============================] - 5s 720ms/step - loss: 1.0979 - accuracy: 0.5491 - val_loss: 1.2350 - val_accuracy: 0.5192
# Epoch 52/60
# 7/7 [==============================] - 5s 728ms/step - loss: 1.1600 - accuracy: 0.4688 - val_loss: 1.0599 - val_accuracy: 0.5312
# Epoch 53/60
# 7/7 [==============================] - 5s 713ms/step - loss: 1.1099 - accuracy: 0.4732 - val_loss: 1.1871 - val_accuracy: 0.5769
# Epoch 54/60
# 7/7 [==============================] - 5s 745ms/step - loss: 1.1106 - accuracy: 0.4821 - val_loss: 0.9715 - val_accuracy: 0.4423
# Epoch 55/60
# 7/7 [==============================] - 5s 706ms/step - loss: 1.1003 - accuracy: 0.5142 - val_loss: 1.0909 - val_accuracy: 0.5312
# Epoch 56/60
# 7/7 [==============================] - 5s 712ms/step - loss: 1.1955 - accuracy: 0.4866 - val_loss: 1.2904 - val_accuracy: 0.4808
# Epoch 57/60
# 7/7 [==============================] - 5s 682ms/step - loss: 1.0931 - accuracy: 0.5283 - val_loss: 1.0719 - val_accuracy: 0.5577
# Epoch 58/60
# 7/7 [==============================] - 5s 730ms/step - loss: 1.1462 - accuracy: 0.5045 - val_loss: 1.5951 - val_accuracy: 0.4688
# Epoch 59/60
# 7/7 [==============================] - 5s 714ms/step - loss: 1.1112 - accuracy: 0.5045 - val_loss: 1.1588 - val_accuracy: 0.4615
# Epoch 60/60
# 7/7 [==============================] - 5s 716ms/step - loss: 1.1674 - accuracy: 0.4821 - val_loss: 0.7274 - val_accuracy: 0.5962

# %% [markdown]
# ## 13. Visualising The Results Generated By The Model With Data Augmentation

# %% [markdown]
# #### 13.1 Training And Validation Accuracy

# %%
train_loss, train_accuracy = model_aug.evaluate_generator(train_generator_aug)
print("\nTraining Accuracy : ", round(100 * train_accuracy, 4), "%")

valid_loss, valid_accuracy = model_aug.evaluate_generator(validation_generator_aug)
print("\nValidation Accuracy : ", round(100 * valid_accuracy, 4), "%")

train_acc = history.history["accuracy"]
valid_acc = history.history["val_accuracy"]

plt.style.use("seaborn")
plt.plot(train_acc, label="Training Accuracy")
plt.plot(valid_acc, label="Validation Accuracy")
plt.title("Training And Validation Accuracy")
plt.legend()
plt.show()
# Out:
# Training Accuracy :  52.0718 %
#
# Validation Accuracy :  53.5714 %

# %%
train_loss = history.history["loss"]
valid_loss = history.history["val_loss"]

plt.style.use("seaborn")
plt.plot(train_loss, label="Training Loss")
plt.plot(valid_loss, label="Validation Loss")
plt.title("Training And Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Although There Is Not Any Improvement In The Accuracy But Data Augmentation Helped Us In Reducing The Overfitting. It's Clearly Visible That The Model Got Rid Of Overfitting.**
